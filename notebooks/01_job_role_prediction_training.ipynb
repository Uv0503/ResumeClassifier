# %% [markdown]
# # AI Resume Screening and Job Fit Prediction System
#
# This notebook explores `data/Resume.csv`, cleans resume text, trains multiple classifiers, and saves the best model artifacts.

# %% [markdown]
# ## 1. Setup

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

import pandas as pd
import matplotlib.pyplot as plt
from preprocessing import load_resume_data, clean_resume_text
from train_model import train_and_evaluate

# %% [markdown]
# ## 2. Load Dataset

# %%
df = load_resume_data(PROJECT_ROOT / 'data' / 'Resume.csv')
df.head()

# %%
print(df.shape)
print(df['Category'].nunique())
df['Category'].value_counts().head(10)

# %% [markdown]
# ## 3. Category Distribution

# %%
counts = df['Category'].value_counts().sort_values()
ax = counts.plot(kind='barh', figsize=(12, 7), title='Resume Category Distribution')
ax.set_xlabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Text Cleaning Preview

# %%
sample_text = df.loc[0, 'Resume']
print(sample_text[:600])
print('--- cleaned ---')
print(clean_resume_text(sample_text)[:600])

# %% [markdown]
# ## 5. Train and Save Models
#
# This calls the same reusable training pipeline used from the terminal.

# %%
summary = train_and_evaluate()
summary

# %% [markdown]
# ## 6. Next Step
#
# Run `streamlit run app/streamlit_app.py` from the project root to use the dashboard.
